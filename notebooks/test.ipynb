# %%
import pandas
#andere imports

# %% [markdown]
# Du musst für einen neuen User aufschreiben, wie er miniconda verwendet! (im readme)
#     - was downloaden (miniconda?)
#     - wo installieren?

# %%
print(2**2)
# Out:
# 4

# %% [markdown]
# kopiert komplette ordnerstruktur
# git add .
#
# Änderungen beschreiben
# git commit -m "Test-Notebook in Ordner verschoben"
